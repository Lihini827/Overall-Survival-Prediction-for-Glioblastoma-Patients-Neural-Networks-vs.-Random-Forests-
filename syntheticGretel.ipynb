# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install gretel-client

# %%
from gretel_client import Gretel

gretel = Gretel(api_key="grtu981f50c11b9aaa1fac014abe1c7db41dad1f367300b02afed1bb09737feea4c3", validate=True)
# Out:
# Using endpoint https://api.gretel.cloud
# Logged in as lihinisangeetha99@gmail.com ✅

# %%
import pandas as pd

# explore the data using pandas
df = pd.read_csv('/content/drive/MyDrive/gbm/smallImpPreProcess_data.csv')
df.head()
# Out:
#     ID  VOLUME_ET  VOLUME_NET  VOLUME_ED  VOLUME_TC  VOLUME_WT  VOLUME_BRAIN  \
# 0  795       1662         384      36268       2046      38314       1469432
# 1  826       4362        4349      15723       8711      24434       1295721
# 2  966      33404       48612      45798      82016     127814       1425843
# 3  728      12114        7587      34086      19701      53787       1403429
# 4  878      34538        7137      65653      41675     107328       1365237
#
#    VOLUME_ET_OVER_NET  VOLUME_ET_OVER_ED  VOLUME_NET_OVER_ED  ...  \
# 0            4.328125           0.045826            0.010588  ...
# 1            1.002989           0.277428            0.276601  ...
# 2            0.687155           0.729377            1.061444  ...
# 3            1.596679           0.355395            0.222584  ...
# 4            4.839288           0.526069            0.108708  ...
#
#    TEXTURE_GLCM_ED_T1_Correlation  TEXTURE_GLCM_ED_T1_SumAverage  \
# 0                         0.94649                       0.007051
# 1                         0.94058                       0.007378
# 2                         0.91358                       0.007076
# 3                         0.95821                       0.007142
# 4                         0.94111                       0.007030
#
#    TEXTURE_GLCM_ED_T1_Variance  TEXTURE_GLCM_ED_T1_Dissimilarity  \
# 0                     0.056453                            3.6532
# 1                     0.072526                            4.3122
# 2                     0.051713                            4.1996
# 3                     0.070721                            3.3383
# 4                     0.062986                            3.9140
#
#    TEXTURE_GLCM_ED_T1_AutoCorrelation  TEXTURE_GLCM_ED_T2_Energy  \
# 0                           1052.9551                   0.001104
# 1                           1192.6283                   0.000778
# 2                           1033.4708                   0.000900
# 3                           1133.3502                   0.000714
# 4                           1071.9954                   0.000973
#
#    TEXTURE_GLCM_ED_T2_Contrast        Age  Survival  survival(high1low0)
# 0                      58.0536  56.208219       558                    1
# 1                     110.1626  61.526027       322                    0
# 2                     100.4861  18.975342       630                    1
# 3                     114.5938  33.887671       370                    0
# 4                      76.2394  54.986301        86                    0
#
# [5 rows x 190 columns]

# %%
trained = gretel.submit_train("tabular-actgan", data_source='/content/drive/MyDrive/gbm/smallImpPreProcess_data.csv')
# Out:
# No project set -> creating a new one...
# Project URL: https://console.gretel.ai/proj_2cWnZF27iVUvNTGbDbC5vHGj0vJ
# Submitting ACTGAN training job...
# Model Docs:https://docs.gretel.ai/reference/synthetics/models/gretel-actgan
# Console URL: https://console.gretel.ai/proj_2cWnZF27iVUvNTGbDbC5vHGj0vJ/models/65d19de8d44339ec2170eef9/activity
# Analyzing input data and checking for auto-params...
# Found 3 auto-params that were set based on input data. epochs 600, batch_size 600, force_conditioning False
# Starting ACTGAN model training... num_epochs 600
# Training data loaded. record_count 76, field_count 190, upsample_count 24
# Training: [██████████████████████████████████████████████████] 600/600 epochs.
# ACTGAN model training complete.
# Sampling records for data preview... num_records 5000
# Preparing privacy filters
# Loaded 0 privacy filters
# Starting privacy filtering
# Privacy filtering complete.
# Sampled 5000 records.
# Creating synthetic quality report (SQS)...
# Finished creating SQS
# Uploading artifacts to Gretel Cloud...
# Upload to Gretel Cloud is completed.

# %%
# view the quality scores
print(trained.report)
# Out:
# GretelReport(
#     synthetic_data_quality_score: 55
#     field_correlation_stability: 47
#     principal_component_stability: 71
#     field_distribution_stability: 50
#     privacy_protection_level: 0
# )

# %%
# display the full report within this notebook
trained.report.display_in_notebook()

# %%
# inspect the synthetic data used to create the report
df_synth_report = trained.fetch_report_synthetic_data()
df_synth_report.head()
# Out:
#     ID  VOLUME_ET  VOLUME_NET  VOLUME_ED  VOLUME_TC  VOLUME_WT  VOLUME_BRAIN  \
# 0  994      34703        1484      26159       6497     144978       1149690
# 1  700       4940        7651      40895       1241     117364       1428686
# 2  505      80419          47     160681      10009      53390       1653413
# 3  733       1037          47       9757       1241     199460       1653413
# 4  994      61896          47      31887      22334      12952       1260816
#
#    VOLUME_ET_OVER_NET  VOLUME_ET_OVER_ED  VOLUME_NET_OVER_ED  ...  \
# 0           32.993413           0.044948            0.000666  ...
# 1            0.186595           1.483644            1.061267  ...
# 2            0.186595           0.424645            0.000666  ...
# 3           36.097330           0.080644            0.437920  ...
# 4            0.238197           1.600206            0.061244  ...
#
#    TEXTURE_GLCM_ED_T1_Correlation  TEXTURE_GLCM_ED_T1_SumAverage  \
# 0                         0.98095                       0.003521
# 1                         0.98095                       0.003521
# 2                         0.98095                       0.007221
# 3                         0.97360                       0.008004
# 4                         0.98095                       0.007612
#
#    TEXTURE_GLCM_ED_T1_Variance  TEXTURE_GLCM_ED_T1_Dissimilarity  \
# 0                     0.082722                            3.2752
# 1                     0.004623                            3.3395
# 2                     0.080052                            2.1604
# 3                     0.082722                            3.3209
# 4                     0.082722                            2.8786
#
#    TEXTURE_GLCM_ED_T1_AutoCorrelation  TEXTURE_GLCM_ED_T2_Energy  \
# 0                            747.6186                   0.001034
# 1                            624.8236                   0.002767
# 2                            385.5484                   0.000529
# 3                            695.3887                   0.003067
# 4                           1396.5795                   0.000529
#
#    TEXTURE_GLCM_ED_T2_Contrast        Age  Survival  survival(high1low0)
# 0                     165.4798  74.405019      1308                    0
# 1                      54.0767  23.075164       341                    0
# 2                      34.9358  76.020861      1204                    0
# 3                     159.1570  27.421830       208                    0
# 4                     161.4831  61.780085       273                    0
#
# [5 rows x 190 columns]

# %%
generated = gretel.submit_generate(trained.model_id, num_records=1000)
# Out:
# Submitting ACTGAN generate job...
# Model Docs:https://docs.gretel.ai/reference/synthetics/models/gretel-actgan
# Console URL: https://console.gretel.ai/proj_2cWnZF27iVUvNTGbDbC5vHGj0vJ/models/65d19de8d44339ec2170eef9/data
# Loading model to worker
# Loading ACTGAN model...
# Sampling 1000 records...
# Preparing privacy filters
# Loaded 0 privacy filters
# Starting privacy filtering
# Privacy filtering complete.
# Uploading artifacts to Gretel Cloud...
# Upload to Gretel Cloud is completed.

# %%
# inspect the generated synthetic data
generated.synthetic_data.head()
# Out:
#     ID  VOLUME_ET  VOLUME_NET  VOLUME_ED  VOLUME_TC  VOLUME_WT  VOLUME_BRAIN  \
# 0  921     111266          47      56716      71637      12952       1286491
# 1  717      71020       22687      85213      14264      43475       1606825
# 2  828       1037          47     124931       7108      40627       1512130
# 3  505      99529        4572      81258      17524      52854       1198211
# 4  505      34234       13307     160681      25047      52598       1653413
#
#    VOLUME_ET_OVER_NET  VOLUME_ET_OVER_ED  VOLUME_NET_OVER_ED  ...  \
# 0            4.810366           0.044948            0.750971  ...
# 1            1.021184           1.008987            0.551142  ...
# 2            5.011988           1.933538            0.051057  ...
# 3            5.015888           1.030468            0.692008  ...
# 4            6.955229           0.044948            0.903356  ...
#
#    TEXTURE_GLCM_ED_T1_Correlation  TEXTURE_GLCM_ED_T1_SumAverage  \
# 0                         0.93100                       0.008004
# 1                         0.98095                       0.008004
# 2                         0.97434                       0.003521
# 3                         0.92700                       0.004215
# 4                         0.96345                       0.008004
#
#    TEXTURE_GLCM_ED_T1_Variance  TEXTURE_GLCM_ED_T1_Dissimilarity  \
# 0                     0.082722                            2.9267
# 1                     0.004623                            5.3171
# 2                     0.004623                            4.9273
# 3                     0.041587                            1.8221
# 4                     0.034334                            2.6206
#
#    TEXTURE_GLCM_ED_T1_AutoCorrelation  TEXTURE_GLCM_ED_T2_Energy  \
# 0                            225.5316                   0.000529
# 1                           1098.2788                   0.001940
# 2                            238.8616                   0.000529
# 3                            535.8738                   0.000529
# 4                           1136.7118                   0.003212
#
#    TEXTURE_GLCM_ED_T2_Contrast        Age  Survival  survival(high1low0)
# 0                      14.4644  84.843836      1731                    0
# 1                      43.1801  18.975342       614                    1
# 2                      65.0408  43.568667         5                    1
# 3                      14.4644  27.065622       249                    1
# 4                      14.4644  60.014864        39                    0
#
# [5 rows x 190 columns]
